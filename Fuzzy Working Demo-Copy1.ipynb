# %%
from fuzzycar import Car
from pynq import Overlay , MMIO

# %%
ol = Overlay("car.bit", ignore_version=True)
print("✔ Overlay 'car.bit' loaded successfully.\n")
# Out:
# ✔ Overlay 'car.bit' loaded successfully.

# %%
car = Car(ol)
# Out:
# Configuring SPI controller...

# %%
gpio = MMIO(ol.axi_gpio_0.mmio.base_addr, 0x10000 , debug=False)

# %%
gpio.write(0x00,0xff)

# %%
car.passenger.read_distance()
# Out:
# 21

# %%
car.driver.read_distance()
# Out:
# 24

# %%
car.pasback.read_distance()
# Out:
# 12

# %%
car.front.read_distance()
# Out:
# 15

# %%
car.drifront.read_distance()
# Out:
# 15

# %%
car.pasfront.read_distance()
# Out:
# 58

# %%
car.drivback.read_distance()
# Out:
# 13

# %%
car.pasback.read_distance()
# Out:
# 12

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
import time
from IPython.display import clear_output

# Define fuzzy variables
driver_sensor = ctrl.Antecedent(np.arange(6, 256, 1), 'driver_sensor')
front_sensor = ctrl.Antecedent(np.arange(6, 256, 1), 'front_sensor')
passenger_sensor = ctrl.Antecedent(np.arange(6, 256, 1), 'passenger_sensor')
rear_driver_sensor = ctrl.Antecedent(np.arange(6, 256, 1), 'rear_driver_sensor')
rear_passenger_sensor = ctrl.Antecedent(np.arange(6, 256, 1), 'rear_passenger_sensor')
turning_degree = ctrl.Consequent(np.arange(500, 2001, 1), 'turning_degree')

# Membership functions for driver_sensor
#driver_sensor['Close'] = fuzz.trapmf(driver_sensor.universe, [6, 6, 55, 65])
#driver_sensor['Medium'] = fuzz.trapmf(driver_sensor.universe, [55, 65, 75, 85])
#driver_sensor['Far'] = fuzz.trapmf(driver_sensor.universe, [75, 85, 255, 255])

# Membership functions for front_sensor
#front_sensor['Close'] = fuzz.trapmf(front_sensor.universe, [6, 6, 45, 55])
#front_sensor['Medium'] = fuzz.trapmf(front_sensor.universe, [45, 55, 65, 75])
#front_sensor['Far'] = fuzz.trapmf(front_sensor.universe, [65, 75, 255, 255])

# Membership functions for passenger_sensor
#passenger_sensor['Close'] = fuzz.trapmf(passenger_sensor.universe, [6, 6, 55, 65])
#passenger_sensor['Medium'] = fuzz.trapmf(passenger_sensor.universe, [55, 65, 75, 85])
#passenger_sensor['Far'] = fuzz.trapmf(passenger_sensor.universe, [75, 85, 255, 255])

# Membership functions for rear_driver_sensor
#rear_driver_sensor['Close'] = fuzz.trapmf(rear_driver_sensor.universe, [6, 6, 55, 65])
#rear_driver_sensor['Medium'] = fuzz.trapmf(rear_driver_sensor.universe, [55, 65, 75, 85])
#rear_driver_sensor['Far'] = fuzz.trapmf(rear_driver_sensor.universe, [75, 85, 255, 255])

# Membership functions for rear_passenger_sensor
#rear_passenger_sensor['Close'] = fuzz.trapmf(rear_passenger_sensor.universe, [6, 6, 55, 65])
#rear_passenger_sensor['Medium'] = fuzz.trapmf(rear_passenger_sensor.universe, [55, 65, 75, 85])
#rear_passenger_sensor['Far'] = fuzz.trapmf(rear_passenger_sensor.universe, [75, 85, 255, 255])

# Driver sensor
driver_sensor['Close'] = fuzz.trapmf(driver_sensor.universe, [6, 6, 12, 20])
driver_sensor['Medium'] = fuzz.trapmf(driver_sensor.universe, [12, 20, 35, 45])
driver_sensor['Far'] = fuzz.trapmf(driver_sensor.universe, [35, 45, 255, 255])

# Front sensor
front_sensor['Close'] = fuzz.trapmf(front_sensor.universe, [6, 6, 12, 20])
front_sensor['Medium'] = fuzz.trapmf(front_sensor.universe, [12, 20, 35, 45])
front_sensor['Far'] = fuzz.trapmf(front_sensor.universe, [35, 45, 255, 255])

# Passenger sensor
passenger_sensor['Close'] = fuzz.trapmf(passenger_sensor.universe, [6, 6, 12, 20])
passenger_sensor['Medium'] = fuzz.trapmf(passenger_sensor.universe, [12, 20, 35, 45])
passenger_sensor['Far'] = fuzz.trapmf(passenger_sensor.universe, [35, 45, 255, 255])

# Rear driver sensor
rear_driver_sensor['Close'] = fuzz.trapmf(rear_driver_sensor.universe, [6, 6, 12, 20])
rear_driver_sensor['Medium'] = fuzz.trapmf(rear_driver_sensor.universe, [12, 20, 35, 45])
rear_driver_sensor['Far'] = fuzz.trapmf(rear_driver_sensor.universe, [35, 45, 255, 255])

# Rear passenger sensor
rear_passenger_sensor['Close'] = fuzz.trapmf(rear_passenger_sensor.universe, [6, 6, 12, 20])
rear_passenger_sensor['Medium'] = fuzz.trapmf(rear_passenger_sensor.universe, [12, 20, 35, 45])
rear_passenger_sensor['Far'] = fuzz.trapmf(rear_passenger_sensor.universe, [35, 45, 255, 255])

# Membership functions for Turning Degree
#turning_degree['Hard Left'] = fuzz.trimf(turning_degree.universe, [1800, 2000, 2000])
#turning_degree['Soft Left'] = fuzz.trimf(turning_degree.universe, [1600, 1700, 1800])
#turning_degree['Straight'] = fuzz.trimf(turning_degree.universe, [1200, 1300, 1400])
#turning_degree['Soft Right'] = fuzz.trimf(turning_degree.universe, [800, 900, 1000])
#turning_degree['Hard Right'] = fuzz.trimf(turning_degree.universe, [600, 600, 700])

turning_degree['Hard Left'] = fuzz.trimf(turning_degree.universe, [500, 500, 800])
turning_degree['Soft Left'] = fuzz.trimf(turning_degree.universe, [500, 800, 1300])
turning_degree['Straight'] = fuzz.trimf(turning_degree.universe, [800, 1300, 1800])
turning_degree['Soft Right'] = fuzz.trimf(turning_degree.universe, [1300, 1800, 2000])
turning_degree['Hard Right'] = fuzz.trimf(turning_degree.universe, [1800, 2000, 2000])

# Define rules
rule1 = ctrl.Rule(driver_sensor['Close'] & front_sensor['Medium'] & ~passenger_sensor['Close'], turning_degree['Soft Right'])
rule2 = ctrl.Rule(driver_sensor['Close'] & ~front_sensor['Close'] & ~passenger_sensor['Close'], turning_degree['Hard Right'])
rule3 = ctrl.Rule(~driver_sensor['Close'] & front_sensor['Medium'] & ~passenger_sensor['Far'], turning_degree['Soft Left'])
rule4 = ctrl.Rule(~driver_sensor['Close'] & front_sensor['Close'] & ~passenger_sensor['Far'], turning_degree['Hard Left'])
rule5 = ctrl.Rule(driver_sensor['Close'] & front_sensor['Far'] & ~passenger_sensor['Close'], turning_degree['Straight'])
rule6 = ctrl.Rule(~driver_sensor['Close'] & front_sensor['Far'] & passenger_sensor['Close'], turning_degree['Straight'])
rule7 = ctrl.Rule(~driver_sensor['Close'] & front_sensor['Far'] & ~passenger_sensor['Close'], turning_degree['Straight'])
rule8 = ctrl.Rule(~driver_sensor['Close'] & front_sensor['Medium'] & passenger_sensor['Far'], turning_degree['Soft Right'])
#rule9 = ctrl.Rule(front_sensor['Close'] & passenger_sensor['Far'], turning_degree['Hard Right'])
rule9 = ctrl.Rule(~driver_sensor['Close'] & front_sensor['Close'] & passenger_sensor['Far'], turning_degree['Hard Right'])
rule10 = ctrl.Rule(driver_sensor['Close'] & front_sensor['Close'] & passenger_sensor['Close'], turning_degree['Straight'])
rule11 = ctrl.Rule(driver_sensor['Medium'] & front_sensor['Medium'] & passenger_sensor['Medium'], turning_degree['Soft Right'])
rule12 = ctrl.Rule(driver_sensor['Medium'] & front_sensor['Close'] & passenger_sensor['Close'], turning_degree['Hard Left'])
rule13 = ctrl.Rule(driver_sensor['Far'] & front_sensor['Close'] & passenger_sensor['Close'], turning_degree['Hard Left'])
rule14 = ctrl.Rule(driver_sensor['Close'] & front_sensor['Close'] & ~passenger_sensor['Close'], turning_degree['Hard Right'])

# New rules for the back sensors
rule15 = ctrl.Rule(rear_driver_sensor['Close'] & rear_passenger_sensor['Close'], turning_degree['Straight'])  # reverse alert
rule16 = ctrl.Rule(rear_driver_sensor['Close'] & ~rear_passenger_sensor['Close'] & front_sensor['Medium'], turning_degree['Soft Right'])
rule17 = ctrl.Rule(rear_passenger_sensor['Close'] & ~rear_driver_sensor['Close'] & front_sensor['Medium'], turning_degree['Soft Left'])
rule18 = ctrl.Rule(rear_driver_sensor['Close'] & rear_passenger_sensor['Far'] & driver_sensor['Far'], turning_degree['Hard Right'])
rule19 = ctrl.Rule(rear_passenger_sensor['Close'] & rear_driver_sensor['Far'] & driver_sensor['Far'], turning_degree['Hard Left'])

# Create control system and simulation
turning_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8, rule9, rule10, rule11, rule12, rule13, rule14, rule15, rule16, rule17, rule18, rule19])
turning_simulation = ctrl.ControlSystemSimulation(turning_ctrl)

# %%
# Just change this value and run the cell again
control_command = 'F'  # Set to 'S' to idle, 'F' to move forward
car.steering.set_pwm_time(50, 1000)
car.motor.set_pwm_time(50, 1600)

# %%
from IPython.display import clear_output
from time import sleep

last_valid_pwm = 1300  # default PWM

try:
    while True:
        # Check value from other cell
        command = control_command.upper()

        if command == 'S':
            car.motor.set_pwm_time(50, 1600)
            car.steering.set_pwm_time(50, 1300)
            print("Motor is idle")

        elif command == 'F':
            # Read sensors
            # Read sensors (FIXED: one-hot GPIO selection)

            # DRIVER
            gpio.write(0x00, 0x01)
            sleep(0.01)
            driver_distance = car.driver.read_distance()
            gpio.write(0x00, 0x00)
            sleep(0.01)

            # PASSENGER
            gpio.write(0x00, 0x02)
            sleep(0.01)
            passenger_distance = car.passenger.read_distance()
            gpio.write(0x00, 0x00)
            sleep(0.01)
    
            # FRONT
            gpio.write(0x00, 0x04)
            sleep(0.01)
            front_distance = car.front.read_distance()
            gpio.write(0x00, 0x00)
            sleep(0.01)

            # PASSENGER FRONT
            gpio.write(0x00, 0x08)
            sleep(0.01)
            pasfront_distance = car.pasfront.read_distance()
            gpio.write(0x00, 0x00)
            sleep(0.01)

            # DRIVER FRONT
            gpio.write(0x00, 0x10)
            sleep(0.01)
            drifront_distance = car.drifront.read_distance()
            gpio.write(0x00, 0x00)
            sleep(0.01)

            # PASSENGER BACK
            gpio.write(0x00, 0x20)
            sleep(0.01)
            pasback_distance = car.pasback.read_distance()
            gpio.write(0x00, 0x00)
            sleep(0.01)
            
            # DRIVE BACK
            gpio.write(0x00, 0x40)
            sleep(0.01)
            drivback_distance = car.drivback.read_distance()
            gpio.write(0x00, 0x00)
            sleep(0.01)

            print("Sensor Readings:")
            print(f"  Driver:       {driver_distance}")
            print(f"  Passenger:    {passenger_distance}")
            print(f"  Front:        {front_distance}")
            print(f"  Pass Front:   {pasfront_distance}")
            print(f"  Drive Front:  {drifront_distance}")
            print(f"  Pass Back:    {pasback_distance}")
            print(f"  Drive Back:   {drivback_distance}")

            # Fuzzy logic
            if driver_distance < 20:
                print("🔴 Driver close — forcing Hard Right")
                car.steering.set_pwm_time(50, 500)
            elif passenger_distance < 20:
                print("🔵 Passenger close — forcing Hard Left")
                car.steering.set_pwm_time(50, 1500)
            else:
                # Normal fuzzy logic
                turning_simulation.reset()
                turning_simulation.input['driver_sensor'] = driver_distance
                turning_simulation.input['front_sensor'] = front_distance
                turning_simulation.input['passenger_sensor'] = passenger_distance
                turning_simulation.input['rear_driver_sensor'] = drivback_distance
                turning_simulation.input['rear_passenger_sensor'] = pasback_distance
                turning_simulation.compute()
            
            #turning_simulation.compute()

                pwm = turning_simulation.output.get('turning_degree')
            
            #print("FUZZY PWM:", pwm)
                print(f"  Driver distance: {driver_distance}")
                print(f"    Close: {fuzz.interp_membership(driver_sensor.universe, driver_sensor['Close'].mf, driver_distance):.2f}")
                print(f"    Medium: {fuzz.interp_membership(driver_sensor.universe, driver_sensor['Medium'].mf, driver_distance):.2f}")
                print(f"    Far: {fuzz.interp_membership(driver_sensor.universe, driver_sensor['Far'].mf, driver_distance):.2f}")

                print(f"  Passenger distance: {passenger_distance}")
                print(f"    Close: {fuzz.interp_membership(passenger_sensor.universe, passenger_sensor['Close'].mf, passenger_distance):.2f}")
                print(f"    Medium: {fuzz.interp_membership(passenger_sensor.universe, passenger_sensor['Medium'].mf, passenger_distance):.2f}")
                print(f"    Far: {fuzz.interp_membership(passenger_sensor.universe, passenger_sensor['Far'].mf, passenger_distance):.2f}")

                print(f"  Front distance: {front_distance}")
                print(f"    Close: {fuzz.interp_membership(front_sensor.universe, front_sensor['Close'].mf, front_distance):.2f}")
                print(f"    Medium: {fuzz.interp_membership(front_sensor.universe, front_sensor['Medium'].mf, front_distance):.2f}")
                print(f"    Far: {fuzz.interp_membership(front_sensor.universe, front_sensor['Far'].mf, front_distance):.2f}")

                print(f"  Fuzzy PWM: {pwm}")
                if pwm is not None:
                    #last_valid_pwm = pwm
                    car.steering.set_pwm_time(50, pwm)

                else:
                    print("⚠️  No valid steering output — using last good PWM value.")
                    car.steering.set_pwm_time(50, last_valid_pwm)

    #------------------ NEW: rear safety + boxed-in logic (numbers only) -------------------------------------------------------
                try:
                    rear_too_close = (pasback_distance < 8) or (drivback_distance < 8)
                except:
                    rear_too_close = False

                # Both front and back too close then stop and determine direction to turn
                if front_distance < 12 and rear_too_close:
                    print("🟥 Boxed in")
                    try:
                        # If passenger front is tighter, steer right; else steer left
                        # Maybe Correction: turn left else turn right
                        if pasfront_distance < drifront_distance:
                            car.steering.set_pwm_time(50, 700)
                        else:
                            car.steering.set_pwm_time(50, 1500)
                    except:
                        car.steering.set_pwm_time(50, 1300)
                    car.motor.set_pwm_time(50, 1600)
                    sleep(0.40)
                    clear_output(wait=True)
                    sleep(0.05)
                    continue

                # back sensor only close 
                elif rear_too_close and not front_distance < 8:
                    print("🔙 Rear obstacle too close — stopping and moving forward to clear.")
                    car.motor.set_pwm_time(50, 1600)
                    try:
                        if pasback_distance is None and drivback_distance is None:
                            car.steering.set_pwm_time(50, 1300)
                        elif pasback_distance is None:
                            car.steering.set_pwm_time(50, 2000)   # assume driver rear closer
                        elif drivback_distance is None:
                            car.steering.set_pwm_time(50, 600)  # assume passenger rear closer
                        elif pasback_distance < drivback_distance:
                            car.steering.set_pwm_time(50, 600)  # passenger rear closer → turn right
                        else:
                            car.steering.set_pwm_time(50, 2000)   # driver rear closer → turn left
                    except:
                        car.steering.set_pwm_time(50, 1300)

                    car.motor.set_pwm_time(50, 1640)
                    sleep(0.3)
                    car.motor.set_pwm_time(50, 1600)
                    clear_output(wait=True)
                    sleep(0.05)
                    continue

                elif front_distance < 8:
                    print("🚨 Obstacle detected — reversing.")
                    car.steering.set_pwm_time(50, 2000 if pasfront_distance < drifront_distance else 600)
                    car.motor.set_pwm_time(50, 1379)
                    sleep(0.1)
                    car.motor.set_pwm_time(50, 1600)
                    sleep(0.1)
                    car.motor.set_pwm_time(50, 1379)
                    sleep(0.2)
                else:
                    car.steering.set_pwm_time(50, pwm)
                    car.motor.set_pwm_time(50, 1690)

            clear_output(wait=True)
            sleep(0.05)
except KeyboardInterrupt:
    car.steering.set_pwm_time(50, 800)
    car.motor.set_pwm_time(50, 1600)
    print("Stopped by user.")
#WIRED
# Out:
# Sensor Readings:
#   Driver:       20
#   Passenger:    27
#   Front:        31
#   Pass Front:   255
#   Drive Front:  67
#   Pass Back:    12
#   Drive Back:   14
# Stopped by user.

# %%
# WIRELESS MODE

# %%
import time
from time import sleep
from IPython.display import clear_output

# Initialize last known good PWM value
last_valid_pwm = 800  # or your desired default center PWM

# MAIN LOOP
while True:
    we = car.lora.transfer([0x00])
    wee = car.lora.transfer([0x00])
    received_chars = set(chr(byte[0]) for byte in (we, wee) if byte and byte[0] not in (0, 255))
    
    if 'S' in received_chars:
        car.motor.set_pwm_time(50, 1600)
        car.steering.set_pwm_time(50, 800)
        print("Motor is idle")
        
    elif 'F' in received_chars:
        # Read sensor values
        gpio.write(0x00, 0x01)
        driver_distance = car.driver.read_distance()
        gpio.write(0x00, 0x02)
        passenger_distance = car.passenger.read_distance()
        gpio.write(0x00, 0x04)
        front_distance = car.front.read_distance()
        gpio.write(0x00, 0x08)
        pasfront_distance = car.pasfront.read_distance()
        gpio.write(0x00, 0x10)
        drifront_distance = car.drifront.read_distance()
        gpio.write(0x00, 0x00)

        print("Sensor Readings:")
        print(f"  Driver:       {driver_distance}")
        print(f"  Passenger:    {passenger_distance}")
        print(f"  Front:        {front_distance}")
        print(f"  Pass Front:   {pasfront_distance}")
        print(f"  Drive Front:  {drifront_distance}")

        # Set fuzzy logic inputs
        turning_simulation.input['driver_sensor'] = passenger_distance
        turning_simulation.input['front_sensor'] = front_distance
        turning_simulation.input['passenger_sensor'] = driver_distance

        # Compute fuzzy logic result
        turning_simulation.compute()
        pwm = turning_simulation.output.get('turning_degree')

        if pwm is not None:
            last_valid_pwm = pwm
            car.steering.set_pwm_time(50, pwm)
        else:
            print("⚠️  No valid steering output — using last good PWM value.")
            car.steering.set_pwm_time(50, last_valid_pwm)

        if front_distance < 9:
            print("🚨 Obstacle detected — reversing.")
            car.steering.set_pwm_time(50, 1000 if pasfront_distance < drifront_distance else 600)
            car.motor.set_pwm_time(50, 1370)
            sleep(0.1)
            car.motor.set_pwm_time(50, 1600)
            sleep(0.1)
            car.motor.set_pwm_time(50, 1370)
            sleep(0.5)
        else:
            car.motor.set_pwm_time(50, 1680)

    clear_output(wait=True)

# %%
from IPython.display import clear_output
import time

last_valid_pwm = 800  # Default center PWM

try:
    while True:
        # Select each sensor with GPIO and read distances
        gpio.write(0x00, 0x01)
        driver_distance = car.driver.read_distance()

        gpio.write(0x00, 0x02)
        passenger_distance = car.passenger.read_distance()

        gpio.write(0x00, 0x04)
        front_distance = car.front.read_distance()

        gpio.write(0x00, 0x08)
        pasfront_distance = car.pasfront.read_distance()

        gpio.write(0x00, 0x10)
        drifront_distance = car.drifront.read_distance()

        gpio.write(0x00, 0x00)  # Deselect all sensors

        # Print current sensor readings
        print("Sensor Readings:")
        print(f"  Driver:       {driver_distance}")
        print(f"  Passenger:    {passenger_distance}")
        print(f"  Front:        {front_distance}")
        print(f"  Pass Front:   {pasfront_distance}")
        print(f"  Drive Front:  {drifront_distance}")

        # Set fuzzy logic inputs
        turning_simulation.input['driver_sensor'] = passenger_distance
        turning_simulation.input['front_sensor'] = front_distance
        turning_simulation.input['passenger_sensor'] = driver_distance

        # Compute fuzzy logic result
        turning_simulation.compute()
        pwm = turning_simulation.output.get('turning_degree')

        # Apply PWM if valid, else use last good value
        if pwm is not None:
            last_valid_pwm = pwm
            car.steering.set_pwm_time(50, pwm)
        else:
            print("⚠️  No valid steering output — using last good PWM value.")
            car.steering.set_pwm_time(50, last_valid_pwm)

        # Obstacle detected — reverse
        if front_distance < 0:
            print("🚨 Obstacle detected — reversing.")
            reverse_pwm = 1000 if pasfront_distance < drifront_distance else 600
            car.steering.set_pwm_time(50, reverse_pwm)
            car.motor.set_pwm_time(50, 1600)
            time.sleep(0.1)
            car.motor.set_pwm_time(50, 1600)
            time.sleep(0.1)
            car.motor.set_pwm_time(50, 1600)
            time.sleep(1)
        else:
            car.motor.set_pwm_time(50, 1600)

        # Short delay and clear output for next loop
        time.sleep(0.001)
        clear_output(wait=True)

except KeyboardInterrupt:
    car.steering.set_pwm_time(50, 800)
    car.motor.set_pwm_time(50, 0)
    print("Stopped by user.")

# %%
car.motor.set_pwm_time(50,1600)
car.steering.set_pwm_time(50,800)

# %%
driver_distance = car.passenger.read_distance()

# %%
from IPython.display import clear_output
from time import sleep

last_valid_pwm = 800  # default PWM

try:
    while True:
        # Check value from other cell
        command = control_command.upper()

        if command == 'S':
            car.motor.set_pwm_time(50, 1600)
            car.steering.set_pwm_time(50, 800)
            print("Motor is idle")

        elif command == 'F':
            # Read sensors
            gpio.write(0x00, 0x06)
            driver_distance = car.driver.read_distance()
            passenger_distance = car.passenger.read_distance()
            front_distance = car.front.read_distance()
            gpio.write(0x00, 0x08)
            pasfront_distance = car.pasfront.read_distance()
            gpio.write(0x00, 0x10)
            drifront_distance = car.drifront.read_distance()

            gpio.write(0x00, 0x20)
            sleep(0.01)
            try:
                pasback_distance = car.pasback.read_distance()
                print("✔ pasback sensor read successfully.")
            except Exception as e:
                print(f"❌ Error reading pasback sensor: {e}")

            gpio.write(0x00, 0x40) 
            sleep(0.01) 
            try:
                drivback_distance = car.drivback.read_distance()
                print("✔ drivback sensor read successfully.")
            except Exception as e:
                print(f"❌ Error reading drivback sensor: {e}")

            gpio.write(0x00, 0x00)

            print("Sensor Readings:")
            print(f"  Driver:       {driver_distance}")
            print(f"  Passenger:    {passenger_distance}")
            print(f"  Front:        {front_distance}")
            print(f"  Pass Front:   {pasfront_distance}")
            print(f"  Drive Front:  {drifront_distance}")
            print(f"  Pass Back:    {pasback_distance}")
            print(f"  Drive Back:   {drivback_distance}")

            # Fuzzy logic
            turning_simulation.input['driver_sensor'] = passenger_distance
            turning_simulation.input['front_sensor'] = front_distance
            turning_simulation.input['passenger_sensor'] = driver_distance
            turning_simulation.input['rear_driver_sensor'] = drivback_distance
            turning_simulation.input['rear_passenger_sensor'] = pasback_distance
            turning_simulation.compute()

            pwm = turning_simulation.output.get('turning_degree')

            if pwm is not None:
                last_valid_pwm = pwm
                car.steering.set_pwm_time(50, pwm)
            else:
                print("⚠️  No valid steering output — using last good PWM value.")
                car.steering.set_pwm_time(50, last_valid_pwm)
                
except KeyboardInterrupt:
    car.steering.set_pwm_time(50, 800)
    car.motor.set_pwm_time(50, 1600)
    print("Stopped by user.")
    #WIRED
# Out:
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       7
#   Passenger:    42
#   Front:        25
#   Pass Front:   23
#   Drive Front:  21
#   Pass Back:    142
#   Drive Back:   25
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       112
#   Passenger:    42
#   Front:        25
#   Pass Front:   23
#   Drive Front:  21
#   Pass Back:    70
#   Drive Back:   29
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       35
#   Passenger:    42
#   Front:        25
#   Pass Front:   23
#   Drive Front:  27
#   Pass Back:    187
#   Drive Back:   26
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       29
#   Passenger:    19
#   Front:        18
#   Pass Front:   20
#   Drive Front:  20
#   Pass Back:    255
#   Drive Back:   8
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       88
#   Passenger:    18
#   Front:        16
#   Pass Front:   38
#   Drive Front:  19
#   Pass Back:    255
#   Drive Back:   8
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       86
#   Passenger:    18
#   Front:        16
#   Pass Front:   16
#   Drive Front:  19
#   Pass Back:    6
#   Drive Back:   8
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       67
#   Passenger:    17
#   Front:        15
#   Pass Front:   16
#   Drive Front:  15
#   Pass Back:    69
#   Drive Back:   8
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       105
#   Passenger:    16
#   Front:        13
#   Pass Front:   16
#   Drive Front:  17
#   Pass Back:    157
#   Drive Back:   38
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       110
#   Passenger:    16
#   Front:        17
#   Pass Front:   18
#   Drive Front:  16
#   Pass Back:    41
#   Drive Back:   8
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       129
#   Passenger:    16
#   Front:        17
#   Pass Front:   15
#   Drive Front:  16
#   Pass Back:    255
#   Drive Back:   8
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       88
#   Passenger:    16
#   Front:        18
#   Pass Front:   21
#   Drive Front:  15
#   Pass Back:    255
#   Drive Back:   8
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       81
#   Passenger:    16
#   Front:        15
#   Pass Front:   39
#   Drive Front:  15
#   Pass Back:    255
#   Drive Back:   9
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       69
#   Passenger:    16
#   Front:        15
#   Pass Front:   19
#   Drive Front:  17
#   Pass Back:    255
#   Drive Back:   9
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       136
#   Passenger:    16
#   Front:        15
#   Pass Front:   39
#   Drive Front:  15
#   Pass Back:    255
#   Drive Back:   9
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       40
#   Passenger:    16
#   Front:        15
#   Pass Front:   19
#   Drive Front:  17
#   Pass Back:    255
#   Drive Back:   9
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       27
#   Passenger:    16
#   Front:        15
#   Pass Front:   39
#   Drive Front:  17
#   Pass Back:    54
#   Drive Back:   8
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       124
#   Passenger:    16
#   Front:        14
#   Pass Front:   38
#   Drive Front:  15
#   Pass Back:    119
#   Drive Back:   9
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       112
#   Passenger:    18
#   Front:        11
#   Pass Front:   37
#   Drive Front:  15
#   Pass Back:    76
#   Drive Back:   10
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       171
#   Passenger:    18
#   Front:        9
#   Pass Front:   53
#   Drive Front:  17
#   Pass Back:    255
#   Drive Back:   9
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       39
#   Passenger:    18
#   Front:        16
#   Pass Front:   54
#   Drive Front:  18
#   Pass Back:    45
#   Drive Back:   10
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       121
#   Passenger:    18
#   Front:        30
#   Pass Front:   55
#   Drive Front:  17
#   Pass Back:    48
#   Drive Back:   38
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       100
#   Passenger:    19
#   Front:        24
#   Pass Front:   57
#   Drive Front:  18
#   Pass Back:    6
#   Drive Back:   10
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       53
#   Passenger:    19
#   Front:        22
#   Pass Front:   53
#   Drive Front:  16
#   Pass Back:    25
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       35
#   Passenger:    19
#   Front:        26
#   Pass Front:   54
#   Drive Front:  13
#   Pass Back:    53
#   Drive Back:   38
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       15
#   Passenger:    19
#   Front:        25
#   Pass Front:   59
#   Drive Front:  13
#   Pass Back:    6
#   Drive Back:   38
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       60
#   Passenger:    19
#   Front:        24
#   Pass Front:   54
#   Drive Front:  13
#   Pass Back:    13
#   Drive Back:   37
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       68
#   Passenger:    19
#   Front:        25
#   Pass Front:   55
#   Drive Front:  13
#   Pass Back:    6
#   Drive Back:   8
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       210
#   Passenger:    19
#   Front:        24
#   Pass Front:   56
#   Drive Front:  13
#   Pass Back:    6
#   Drive Back:   8
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       13
#   Passenger:    19
#   Front:        25
#   Pass Front:   15
#   Drive Front:  13
#   Pass Back:    255
#   Drive Back:   38
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       15
#   Passenger:    19
#   Front:        29
#   Pass Front:   40
#   Drive Front:  13
#   Pass Back:    29
#   Drive Back:   37
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       10
#   Passenger:    19
#   Front:        25
#   Pass Front:   58
#   Drive Front:  13
#   Pass Back:    129
#   Drive Back:   8
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       15
#   Passenger:    19
#   Front:        26
#   Pass Front:   16
#   Drive Front:  13
#   Pass Back:    255
#   Drive Back:   8
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       50
#   Passenger:    19
#   Front:        28
#   Pass Front:   54
#   Drive Front:  13
#   Pass Back:    98
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       206
#   Passenger:    19
#   Front:        20
#   Pass Front:   60
#   Drive Front:  13
#   Pass Back:    75
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       15
#   Passenger:    19
#   Front:        25
#   Pass Front:   55
#   Drive Front:  13
#   Pass Back:    38
#   Drive Back:   8
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       15
#   Passenger:    19
#   Front:        25
#   Pass Front:   48
#   Drive Front:  13
#   Pass Back:    72
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       76
#   Passenger:    19
#   Front:        25
#   Pass Front:   55
#   Drive Front:  13
#   Pass Back:    25
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       160
#   Passenger:    19
#   Front:        25
#   Pass Front:   55
#   Drive Front:  13
#   Pass Back:    52
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       63
#   Passenger:    19
#   Front:        25
#   Pass Front:   50
#   Drive Front:  13
#   Pass Back:    255
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       15
#   Passenger:    19
#   Front:        24
#   Pass Front:   55
#   Drive Front:  13
#   Pass Back:    255
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       70
#   Passenger:    19
#   Front:        31
#   Pass Front:   50
#   Drive Front:  13
#   Pass Back:    11
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       138
#   Passenger:    19
#   Front:        28
#   Pass Front:   51
#   Drive Front:  13
#   Pass Back:    65
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       161
#   Passenger:    19
#   Front:        27
#   Pass Front:   51
#   Drive Front:  13
#   Pass Back:    139
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       15
#   Passenger:    19
#   Front:        24
#   Pass Front:   50
#   Drive Front:  13
#   Pass Back:    30
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       88
#   Passenger:    19
#   Front:        25
#   Pass Front:   49
#   Drive Front:  13
#   Pass Back:    120
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       72
#   Passenger:    18
#   Front:        6
#   Pass Front:   51
#   Drive Front:  13
#   Pass Back:    255
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       15
#   Passenger:    19
#   Front:        16
#   Pass Front:   22
#   Drive Front:  13
#   Pass Back:    40
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       59
#   Passenger:    19
#   Front:        26
#   Pass Front:   60
#   Drive Front:  12
#   Pass Back:    41
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       17
#   Passenger:    19
#   Front:        6
#   Pass Front:   56
#   Drive Front:  15
#   Pass Back:    6
#   Drive Back:   8
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       78
#   Passenger:    19
#   Front:        28
#   Pass Front:   51
#   Drive Front:  14
#   Pass Back:    255
#   Drive Back:   9
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       114
#   Passenger:    19
#   Front:        35
#   Pass Front:   55
#   Drive Front:  14
#   Pass Back:    255
#   Drive Back:   9
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       18
#   Passenger:    19
#   Front:        15
#   Pass Front:   54
#   Drive Front:  13
#   Pass Back:    255
#   Drive Back:   8
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       98
#   Passenger:    19
#   Front:        19
#   Pass Front:   54
#   Drive Front:  13
#   Pass Back:    81
#   Drive Back:   8
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       90
#   Passenger:    19
#   Front:        10
#   Pass Front:   56
#   Drive Front:  13
#   Pass Back:    6
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       99
#   Passenger:    19
#   Front:        16
#   Pass Front:   64
#   Drive Front:  13
#   Pass Back:    255
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       75
#   Passenger:    19
#   Front:        6
#   Pass Front:   46
#   Drive Front:  13
#   Pass Back:    219
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       7
#   Passenger:    19
#   Front:        6
#   Pass Front:   51
#   Drive Front:  13
#   Pass Back:    96
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       117
#   Passenger:    19
#   Front:        6
#   Pass Front:   47
#   Drive Front:  13
#   Pass Back:    93
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       60
#   Passenger:    19
#   Front:        17
#   Pass Front:   63
#   Drive Front:  13
#   Pass Back:    72
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       134
#   Passenger:    19
#   Front:        15
#   Pass Front:   63
#   Drive Front:  13
#   Pass Back:    255
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       255
#   Passenger:    19
#   Front:        174
#   Pass Front:   63
#   Drive Front:  13
#   Pass Back:    6
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       80
#   Passenger:    19
#   Front:        16
#   Pass Front:   17
#   Drive Front:  13
#   Pass Back:    140
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       94
#   Passenger:    19
#   Front:        20
#   Pass Front:   16
#   Drive Front:  13
#   Pass Back:    43
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       67
#   Passenger:    19
#   Front:        20
#   Pass Front:   64
#   Drive Front:  13
#   Pass Back:    41
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       37
#   Passenger:    19
#   Front:        116
#   Pass Front:   16
#   Drive Front:  13
#   Pass Back:    21
#   Drive Back:   7
# ✔ pasback sensor read successfully.
# ✔ drivback sensor read successfully.
# Sensor Readings:
#   Driver:       95
#   Passenger:    19
#   Front:        16
#   Pass Front:   64
#   Drive Front:  13
#   Pass Back:    20
#   Drive Back:   7

# %%
# %pip install scikit_fuzzy-0.5.0-py2.py3-none-any.whl
# Out:
# Processing ./scikit_fuzzy-0.5.0-py2.py3-none-any.whl
# Installing collected packages: scikit-fuzzy
# Successfully installed scikit-fuzzy-0.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import skfuzzy
print("Installed successfully")
# Out:
# Installed successfully
